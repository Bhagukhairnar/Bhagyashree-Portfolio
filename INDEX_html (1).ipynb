# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Bhagyashree Khairnar - Portfolio</title>
    <link rel="stylesheet" href="style.css">
    <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@300;500;700&display=swap" rel="stylesheet">
</head>
<body>
    <!-- Header -->
    <header class="hero">
        <div class="container">
            <h1 class="fade-in">Bhagyashree Khairnar</h1>
            <p class="fade-in delay-1">Python Developer | Full-Stack Enthusiast | Problem Solver</p>
            <div class="contact-info fade-in delay-2">
                <a href="mailto:bhagikhairnar99@gmail.com">📧 Email</a>
                <a href="tel:+919049308591">📞 Call</a>
                <a href="https://www.linkedin.com/in/bhagyashree-khairnar-204441349" target="_blank">🔗 LinkedIn</a>
            </div>
        </div>
    </header>

    <!-- About -->
    <section id="about" class="container fade-up">
        <h2>About Me</h2>
        <p>Dynamic Python Developer Intern with hands-on experience in Python, Django, and MySQL.
        Skilled in debugging, problem-solving, and building robust applications.
        Passionate about delivering high-quality solutions in collaborative environments.</p>
    </section>

    <!-- Skills -->
    <section id="skills" class="container fade-up">
        <h2>Technical Skills</h2>
        <div class="skills-grid">
            <span>Python</span>
            <span>Django</span>
            <span>HTML</span>
            <span>CSS</span>
            <span>Bootstrap</span>
            <span>MySQL</span>
            <span>Git</span>
            <span>Linux</span>
            <span>Windows</span>
            <span>VS Code</span>
        </div>
    </section>

    <!-- Projects -->
    <section id="projects" class="container fade-up">
        <h2>Projects</h2>
        <div class="project-grid">
            <div class="project-card">
                <h3>🏠 Property Buy or Sell</h3>
                <p>Dynamic PHP-MySQL web app where users can explore and manage property listings. Includes admin panel for property management.</p>
            </div>
            <div class="project-card">
                <h3>🚌 Travel Management Service</h3>
                <p>Standalone PHP-MySQL application for bus route generation and ticket booking.</p>
            </div>
        </div>
    </section>

    <!-- Education -->
    <section id="education" class="container fade-up">
        <h2>Education</h2>
        <ul>
            <li>M.Sc. Computer Science, K.K. Wagh College, Pune (76%)</li>
            <li>B.Sc. Computer Science, K.K. Wagh College, Pune (57.36%)</li>
            <li>H.S.C., Janta English School & Jr. College (50%)</li>
            <li>S.S.C., Janta English School & Jr. College (73%)</li>
        </ul>
    </section>

    <!-- Certifications -->
    <section id="certifications" class="container fade-up">
        <h2>Certifications</h2>
        <p>Full-stack web development & AI with Python (Django)</p>
    </section>

    <!-- Footer -->
    <footer>
        <p>© 2025 Bhagyashree Khairnar | Designed with ❤️</p>
    </footer>

    <script src="script.js"></script>
</body>
</html>
